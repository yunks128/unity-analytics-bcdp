# %% [markdown]
# # Running an OGC Application in an ADES

# %%
import time
import os
import kubernetes
from ades_client import create_api_client

# %% [markdown]
# Set up API client interfaces for Kubernetes and ADES

# %%
kubernetes.config.load_config()
kube_client = kubernetes.client.CoreV1Api()
ades_client = create_api_client('127.0.0.1', 5000)

# %% [markdown]
# Deploy the application as a process

# %%
ades_client.deployProcess(params=dict(proc='https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/application_descriptor.json'))
# Out:
# {'deploymentResult': {'processSummary': {'executionUnit': [{'href': 'docker://jplzhan/ci-generated-images:unity-sds.unity-analytics-bcdp.main'}],
#    'immediateDeployment': True,
#    'processDescription': {'jobControlOptions': ['async-execute'],
#     'outputTransmission': ['reference'],
#     'process': {'abstract': 'Application Package Demo',
#      'id': 'unity-sds.unity-analytics-bcdp.main-3.0.0',
#      'inputs': [{'id': 'workflow_variable',
#        'literalDataDomains': [{'dataType': {'name': ['string']}}],
#        'title': 'Automatically detected using papermill.'},
#       {'id': 'workflow_dataset_path_name',
#        'literalDataDomains': [{'dataType': {'name': ['string']}}],
#        'title': 'Automatically detected using papermill.'},
#       {'id': 'workflow_base_dataset_url',
#        'literalDataDomains': [{'dataType': {'name': ['string']}}],
#        'title': 'Automatically detected using papermill.'},
#       {'id': 'workflow_aws_secret_access_key',
#        'literalDataDomains': [{'dataType': {'name': ['string']}}],
#        'title': 'Automatically detected using papermill.'},
#       {'id': 'workflow_aws_access_key_id',
#        'literalDataDomains': [{'dataType': {'name': ['string']}}],
#        'title': 'Automatically detected using papermill.'},
#       {'id': 'workflow_aws_session_token',
#        'literalDataDomains': [{'dataType': {'name': ['string']}}],
#        'title': 'Automatically detected using papermill.'}],
#      'keywords': ['Demo'],
#      'outputs': [],
#      'owsContext': {'offering': {'content': {'href': 'https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl'}}},
#      'title': 'BCDP'},
#     'processVersion': '3.0.0'}}}}

# %% [markdown]
# Show process information from ADES

# %%
processes = ades_client.getProcesses()
processes
# Out:
# {'processes': [{'abstract': 'Application Package Demo',
#    'executionUnit': 'docker://jplzhan/ci-generated-images:unity-sds.unity-analytics-bcdp.main',
#    'id': 'unity-sds.unity-analytics-bcdp.main-3.0.0',
#    'immediateDeployment': 'true',
#    'jobControlOptions': ['async-execute'],
#    'keywords': 'Demo',
#    'outputTransmission': ['reference'],
#    'owsContextURL': 'https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl',
#    'processVersion': '3.0.0',
#    'title': 'BCDP'}]}

# %% [markdown]
# Execute a job with given input parameters

# %%
proc = processes['processes'][0]
data = dict(workflow_base_dataset_url='s3://unity-dev-as-s3-analytics/data/',
            workflow_dataset_path_name='CORDEX_Africa',
            workflow_variable='pr',
            workflow_aws_access_key_id=os.environ['AWS_ACCESS_KEY_ID'],
            workflow_aws_secret_access_key=os.environ['AWS_SECRET_ACCESS_KEY'],
            workflow_aws_session_token=os.environ['AWS_SESSION_TOKEN'])
job = ades_client.execute(proc['id'], json=data)
job
# Out:
# {'jobID': 'unity-sds.unity-analytics-bcdp.main-3.0.0-0083d93af77e542be7df64d1d5b3a3da4afd0b44',
#  'status': 'accepted'}

# %% [markdown]
# Print job info

# %%
jobs = ades_client.getJobList(proc['id'])
jobs
# Out:
# {'jobs': [{'backend_info': '{"status": "accepted", "k8s_tmpout_pvc_name": "tmpout-rd4fir0ojbp2", "k8s_output_pvc_name": "output-data-rd4fir0ojbp2", "k8s_job_id": "calrissian-job-rd4fir0ojbp2", "api_response": {"apiVersion": "batch/v1", "kind": "Job", "metadata": {"creationTimestamp": "2022-08-15T19:56:43+00:00", "generation": 1, "labels": {"controller-uid": "a899f82e-bd6f-4367-9c24-0a81a365bc13", "job-name": "calrissian-job-rd4fir0ojbp2"}, "managedFields": [{"apiVersion": "batch/v1", "fieldsType": "FieldsV1", "fieldsV1": {"f:spec": {"f:backoffLimit": {}, "f:completionMode": {}, "f:completions": {}, "f:parallelism": {}, "f:suspend": {}, "f:template": {"f:spec": {"f:containers": {"k:{\\"name\\":\\"calrissian-job\\"}": {".": {}, "f:args": {}, "f:command": {}, "f:env": {".": {}, "k:{\\"name\\":\\"CALRISSIAN_DELETE_PODS\\"}": {".": {}, "f:name": {}, "f:value": {}}, "k:{\\"name\\":\\"CALRISSIAN_POD_NAME\\"}": {".": {}, "f:name": {}, "f:valueFrom": {".": {}, "f:fieldRef": {}}}}, "f:envFrom": {}, "f:image": {}, "f:imagePullPolicy": {}, "f:name": {}, "f:resources": {}, "f:terminationMessagePath": {}, "f:terminationMessagePolicy": {}, "f:volumeMounts": {".": {}, "k:{\\"mountPath\\":\\"/calrissian/output-data\\"}": {".": {}, "f:mountPath": {}, "f:name": {}}, "k:{\\"mountPath\\":\\"/calrissian/tmpout\\"}": {".": {}, "f:mountPath": {}, "f:name": {}}}}}, "f:dnsPolicy": {}, "f:initContainers": {".": {}, "k:{\\"name\\":\\"init-volumes\\"}": {".": {}, "f:args": {}, "f:command": {}, "f:image": {}, "f:imagePullPolicy": {}, "f:name": {}, "f:resources": {}, "f:terminationMessagePath": {}, "f:terminationMessagePolicy": {}, "f:volumeMounts": {".": {}, "k:{\\"mountPath\\":\\"/calrissian/output-data\\"}": {".": {}, "f:mountPath": {}, "f:name": {}}, "k:{\\"mountPath\\":\\"/calrissian/tmpout\\"}": {".": {}, "f:mountPath": {}, "f:name": {}}}}}, "f:restartPolicy": {}, "f:schedulerName": {}, "f:securityContext": {}, "f:terminationGracePeriodSeconds": {}, "f:volumes": {".": {}, "k:{\\"name\\":\\"output-data-rd4fir0ojbp2\\"}": {".": {}, "f:name": {}, "f:persistentVolumeClaim": {".": {}, "f:claimName": {}}}, "k:{\\"name\\":\\"tmpout-rd4fir0ojbp2\\"}": {".": {}, "f:name": {}, "f:persistentVolumeClaim": {".": {}, "f:claimName": {}}}}}}}}, "manager": "OpenAPI-Generator", "operation": "Update", "time": "2022-08-15T19:56:43+00:00"}], "name": "calrissian-job-rd4fir0ojbp2", "namespace": "ades", "resourceVersion": "247986", "uid": "a899f82e-bd6f-4367-9c24-0a81a365bc13"}, "spec": {"backoffLimit": 0, "completions": 1, "parallelism": 1, "selector": {"matchLabels": {"controller-uid": "a899f82e-bd6f-4367-9c24-0a81a365bc13"}}, "template": {"metadata": {"labels": {"controller-uid": "a899f82e-bd6f-4367-9c24-0a81a365bc13", "job-name": "calrissian-job-rd4fir0ojbp2"}}, "spec": {"containers": [{"args": ["calrissian-job-rd4fir0ojbp2", "--debug", "--leave-outputs", "--leave-tmpdir", "--stdout", "/calrissian/output-data/output-data-rd4fir0ojbp2/docker-output.json", "--stderr", "/calrissian/output-data/output-data-rd4fir0ojbp2/docker-stderr.log", "--max-ram", "1024Mi", "--max-cores", "1", "--tmp-outdir-prefix", "/calrissian/tmpout/tmpout-rd4fir0ojbp2/", "--outdir", "/calrissian/output-data/output-data-rd4fir0ojbp2/", "--usage-report", "/calrissian/output-data/output-data-rd4fir0ojbp2/docker-usage.json", "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl", "--workflow_base_dataset_url", "s3://unity-dev-as-s3-analytics/data/", "--workflow_dataset_path_name", "CORDEX_Africa", "--workflow_variable", "pr", "--workflow_aws_access_key_id", "ASIA434CXH3E3BCHFAN4", "--workflow_aws_secret_access_key", "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z", "--workflow_aws_session_token", "..."], "command": ["/app/run_and_dump_usage.sh"], "env": [{"name": "CALRISSIAN_POD_NAME", "valueFrom": {"fieldRef": {"apiVersion": "v1", "fieldPath": "metadata.name"}}}, {"name": "CALRISSIAN_DELETE_PODS", "value": "false"}], "envFrom": [{"secretRef": {"name": "aws-creds"}}], "image": "py ...
#    'inputs': '{"workflow_base_dataset_url": "s3://unity-dev-as-s3-analytics/data/", "workflow_dataset_path_name": "CORDEX_Africa", "workflow_variable": "pr", "workflow_aws_access_key_id": "ASIA434CXH3E3BCHFAN4", "workflow_aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z", "workflow_aws_session_token": "..."}',
#    'jobID': 'unity-sds.unity-analytics-bcdp.main-3.0.0-0083d93af77e542be7df64d1d5b3a3da4afd0b44',
#    'metrics': '{}',
#    'procID': 'unity-sds.unity-analytics-bcdp.main-3.0.0',
#    'status': 'accepted',
#    'timestamp': '2022-08-15T19:56:43Z'}]}

# %% [markdown]
# Log the job output from k8s

# %%
time.sleep(5)
pod = kube_client.list_namespaced_pod('ades').items[0].metadata.name
for line in kube_client.read_namespaced_pod_log(pod, 'ades', follow=True, _preload_content=False).stream():
    print(line.decode())
# Out:
# INFO calrissian 0.10.0 (cwltool 3.1.20220512223411)
#
# https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/stage_in.cwl:6:3: Warning: checking
#
#                                                                                         item
#
#                                                                                         Warning:   Field
#
#                                                                                         `class` contains
#
#                                                                                         undefined reference
#
#                                                                                         to
#
#                                                                                         `http://commonwl.org/cwltool#Secrets`
#
# INFO https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/stage_in.cwl:6:3: Unknown hint
#
#                                                                                         http://commonwl.org/cwltool#Secrets
#
# https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/stage_out.cwl:6:3: Warning: checking
#
#                                                                                          item
#
#                                                                                          Warning:   Field
#
#                                                                                          `class` contains
#
#                                                                                          undefined reference
#
#                                                                                          to
#
#                                                                                          `http://commonwl.org/cwltool#Secrets`
#
# INFO https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/stage_out.cwl:6:3: Unknown hint
#
#                                                                                          http://commonwl.org/cwltool#Secrets
#
# DEBUG Parsed job order from command line: {
#
#     "id": "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl",
#
#     "workflow_aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "workflow_aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "workflow_aws_session_token": "...",
#
#     "workflow_base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "workflow_dataset_path_name": "CORDEX_Africa",
#
#     "workflow_variable": "pr"
#
# }
#
# DEBUG Starting ThreadPoolJobExecutor.run_jobs: total_resources=[ram: 1073.741824, cores: 1.0], max_workers=None
#
# DEBUG [workflow ] initialized from https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl
#
# DEBUG wait_for_completion with 0 futures
#
# DEBUG [workflow ] inputs {
#
#     "workflow_aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "workflow_aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "workflow_aws_session_token": "...",
#
#     "workflow_base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "workflow_dataset_path_name": "CORDEX_Africa",
#
#     "workflow_variable": "pr"
#
# }
#
# DEBUG [workflow ] job step https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out not ready
#
# INFO [workflow ] starting step stage_in
#
# DEBUG [step stage_in] job input {
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/aws_session_token": "...",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/dataset_path_name": "CORDEX_Africa"
#
# }
#
# DEBUG [step stage_in] evaluated job input to {
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/aws_session_token": "...",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/dataset_path_name": "CORDEX_Africa"
#
# }
#
# INFO [step stage_in] start
#
# DEBUG [job stage_in] initializing from https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/stage_in.cwl as part of step stage_in
#
# DEBUG [job stage_in] {
#
#     "aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "aws_session_token": "...",
#
#     "base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "dataset_path_name": "CORDEX_Africa"
#
# }
#
# DEBUG [job stage_in] path mappings is {}
#
# DEBUG [job stage_in] command line bindings is [
#
#     {
#
#         "position": [
#
#             -1000000,
#
#             0
#
#         ],
#
#         "datum": "sh"
#
#     },
#
#     {
#
#         "position": [
#
#             0,
#
#             0
#
#         ],
#
#         "datum": "-c"
#
#     },
#
#     {
#
#         "position": [
#
#             0,
#
#             1
#
#         ],
#
#         "valueFrom": "cat $HOME/.aws/credentials && aws s3 cp --profile saml-pub --recursive $(inputs.base_dataset_url)$(inputs.dataset_path_name) $(inputs.dataset_path_name)"
#
#     }
#
# ]
#
# DEBUG wait_for_completion with 0 futures
#
# DEBUG [workflow ] job step https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process not ready
#
# DEBUG [workflow ] job step https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out not ready
#
# DEBUG [workflow ] job step https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process not ready
#
# DEBUG allocate [ram: 0, cores: 0] from available [ram: 1073.741824, cores: 1.0]
#
# INFO [workflow ] start
#
# DEBUG restore [ram: 0, cores: 0] to available [ram: 1073.741824, cores: 1.0]
#
# DEBUG allocate [ram: 256, cores: 1] from available [ram: 1073.741824, cores: 1.0]
#
# DEBUG wait_for_completion with 2 futures
#
# DEBUG [workflow ] job step https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out not ready
#
# DEBUG [workflow ] job step https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process not ready
#
# DEBUG wait_for_completion with 1 futures
#
# DEBUG [job stage_in] initial work dir {
#
#     "_:a44ed2b4-b6ed-4f0a-91ed-914f74ee7a83": [
#
#         "[saml-pub]\noutput = json\nregion = us-west-2\naws_access_key_id = ASIA434CXH3E3BCHFAN4\naws_secret_access_key = k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z\naws_session_token = ...\n",
#
#         "/KQUXQs/.aws/credentials",
#
#         "CreateFile",
#
#         true
#
#     ]
#
# }
#
# Building resources spec from {'cores': 1, 'ram': 256}
#
# --------------------------------------------------------------------------------
#
# apiVersion: v1
#
# kind: Pod
#
# metadata:
#
#   labels:
#
#     job-name: calrissian-job-rd4fir0ojbp2
#
#   name: stage-in-pod-mforudbt
#
# spec:
#
#   containers:
#
#   - args:
#
#     - sh -c 'cat $HOME/.aws/credentials && aws s3 cp --profile saml-pub --recursive
#
#       s3://unity-dev-as-s3-analytics/data/CORDEX_Africa CORDEX_Africa'
#
#     command:
#
#     - /bin/sh
#
#     - -c
#
#     env:
#
#     - name: HOME
#
#       value: /KQUXQs
#
#     - name: TMPDIR
#
#       value: /tmp
#
#     image: jplzhan/ci-generated-images:unity-sds.unity-analytics-bcdp.main
#
#     imagePullPolicy: Always
#
#     name: stage-in-container
#
#     resources:
#
#       requests:
#
#         cpu: '1'
#
#         memory: 256Mi
#
#     volumeMounts:
#
#     - mountPath: /KQUXQs
#
#       name: tmpout-rd4fir0ojbp2
#
#       readOnly: false
#
#       subPath: tmpout-rd4fir0ojbp2/npg8by3y
#
#     - mountPath: /tmp
#
#       name: tmpdir
#
#     workingDir: /KQUXQs
#
#   initContainers: []
#
#   restartPolicy: Never
#
#   securityContext:
#
#     runAsGroup: 0
#
#     runAsUser: 1001
#
#   volumes:
#
#   - name: tmpout-rd4fir0ojbp2
#
#     persistentVolumeClaim:
#
#       claimName: tmpout-rd4fir0ojbp2
#
#       readOnly: false
#
#   - name: output-data-rd4fir0ojbp2
#
#     persistentVolumeClaim:
#
#       claimName: output-data-rd4fir0ojbp2
#
#       readOnly: false
#
#   - emptyDir: {}
#
#     name: tmpdir
#
# --------------------------------------------------------------------------------
#
#
#
# Created k8s pod name stage-in-pod-mforudbt with id ef4ec293-74e9-4b61-b58f-5e743310d142
#
# PodMonitor adding stage-in-pod-mforudbt
#
# k8s pod 'stage-in-pod-mforudbt' started
#
# [stage-in-pod-mforudbt] follow_logs start
#
# [stage-in-pod-mforudbt] [saml-pub]
#
# [stage-in-pod-mforudbt] output = json
#
# [stage-in-pod-mforudbt] region = us-west-2
#
# [stage-in-pod-mforudbt] aws_access_key_id = ASIA434CXH3E3BCHFAN4
#
# [stage-in-pod-mforudbt] aws_secret_access_key = k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z
#
# [stage-in-pod-mforudbt] aws_session_token = ...
#
# Completed 60.2 MiB/1.3 GiB (27.3 MiB/s) with 36 file(s) remaining  ith 36 file(s) remaining
# with 36 file(s) remainin
#
# Completed 120.5 MiB/1.3 GiB (31.6 MiB/s) with 36 file(s) remaining
# B/s) with 36 file(s) rem
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tas.nc to CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tas.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmax.nc to CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmax.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_pr.nc to CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_pr.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmin.nc to CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmin.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_clt.nc
#
# Completed 278.0 MiB/1.3 GiB (12.7 MiB/s) with 31 file(s) remainingith 31 file(s) remaining
# 8.3 MiB/1.3 GiB (12.7 Mi
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_clt.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tas.nc to CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tas.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc to CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_pr.nc to CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_pr.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmin.nc to CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmin.nc
#
# Completed 468.4 MiB/1.3 GiB (9.7 MiB/s) with 26 file(s) remaining ith 26 file(s) remaining
# 8.6 MiB/1.3 GiB (9.7 MiB
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmin.nc to CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmin.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tas.nc to CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tas.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmax.nc to CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmax.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_clt.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_pr.nc to CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_pr.nc
#
# Completed 637.0 MiB/1.3 GiB (9.1 MiB/s) with 21 file(s) remainingith 21 file(s) remaining
# Completed 637.2
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_clt.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tas.nc to CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tas.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_pr.nc to CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_pr.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmax.nc to CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmax.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmin.nc to CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmin.nc
#
# Completed 811.5 MiB/1.3 GiB (8.6 MiB/s) with 16 file(s) remainingith 16 file(s) remaining
# Completed 811.7
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_KNMI-RACMO2.2b_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_KNMI-RACMO2.2b_CTL_ERAINT_MM_50km_clt.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_clt.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_pr.nc to CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_pr.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmax.nc to CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmax.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tas.nc to CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tas.nc
#
# Completed 982.7 MiB/1.3 GiB (8.3 MiB/s) with 11 file(s) remainingith 11 file(s) remaining
# Completed 983.0
#
# Completed 1.0 GiB/1.3 GiB (8.2 MiB/s) with 11 file(s) remaining   maining
# 2 MiB/s) with 11 file(s)
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tas.nc to CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tas.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_pr.nc to CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_pr.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmin.nc to CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmin.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_clt.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_pr.nc to CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_pr.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmax.nc to CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmax.nc
#
# Completed 1.2 GiB/1.3 GiB (8.0 MiB/s) with 5 file(s) remainingwith 5 file(s) remaining
# Comple(s) remaining
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_clt.nc to CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_clt.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmin.nc to CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmin.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tas.nc to CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tas.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmin.nc to CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmin.nc
#
# download: s3://unity-dev-as-s3-analytics/data/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc to CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc
#
# [stage-in-pod-mforudbt] follow_logs end
#
# Handling terminated pod name stage-in-pod-mforudbt with id ef4ec293-74e9-4b61-b58f-5e743310d142
#
# handling completion with 0
#
# CALRISSIAN_DELETE_PODS=false(<class 'str'>)
#
# returning False
#
# DEBUG [step stage_in] produced output {
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_in/dataset_path": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa",
#
#         "basename": "CORDEX_Africa",
#
#         "nameroot": "CORDEX_Africa",
#
#         "nameext": "",
#
#         "class": "Directory"
#
#     }
#
# }
#
# INFO [step stage_in] completed success
#
# shutil.rmtree(/tmp/6qur3z_2, True)
#
# DEBUG restore [ram: 256, cores: 1] to available [ram: 817.741824, cores: 0.0]
#
# DEBUG [workflow ] job step https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out not ready
#
# INFO [workflow ] starting step process
#
# DEBUG [step process] job input {
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process/dataset_path": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa",
#
#         "basename": "CORDEX_Africa",
#
#         "nameroot": "CORDEX_Africa",
#
#         "nameext": "",
#
#         "class": "Directory"
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process/variable": "pr"
#
# }
#
# DEBUG [step process] evaluated job input to {
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process/dataset_path": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa",
#
#         "basename": "CORDEX_Africa",
#
#         "nameroot": "CORDEX_Africa",
#
#         "nameext": "",
#
#         "class": "Directory"
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process/variable": "pr"
#
# }
#
# INFO [step process] start
#
# DEBUG [job process] initializing from https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/process.cwl as part of step process
#
# DEBUG [job process] {
#
#     "dataset_path": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa",
#
#         "basename": "CORDEX_Africa",
#
#         "nameroot": "CORDEX_Africa",
#
#         "nameext": "",
#
#         "class": "Directory",
#
#         "listing": [
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "basename": "AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "size": 37446260
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "basename": "AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "size": 37287280
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "basename": "AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "size": 38071552
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "basename": "AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "size": 37446432
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "basename": "AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "size": 37443992
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "basename": "AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "size": 38537932
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "basename": "AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "size": 38070116
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "basename": "AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "size": 37287264
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 38069244
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "basename": "AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "size": 38068580
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "basename": "AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "size": 37443880
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "basename": "AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "size": 36198076
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "basename": "AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "size": 38071412
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "basename": "AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "size": 38070088
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "basename": "AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "size": 36198104
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_KNMI-RACMO2.2b_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_KNMI-RACMO2.2b_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 37756448
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "basename": "AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "size": 37443776
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "basename": "AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "size": 38070116
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "basename": "AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "size": 38537964
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "basename": "AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "size": 37443512
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 37443860
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "basename": "AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "size": 37287280
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 38072096
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "basename": "AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "size": 36197936
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "basename": "AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "size": 38069720
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "basename": "AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "size": 36198104
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "basename": "AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "size": 38537964
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "basename": "AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "size": 37443992
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "basename": "AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#                 "size": 37446260
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "basename": "AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tas.nc",
#
#                 "size": 37446120
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 38537864
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "basename": "AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_pr.nc",
#
#                 "size": 38537712
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 36198160
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 37445976
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "basename": "AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                 "size": 38071552
#
#             },
#
#             {
#
#                 "class": "File",
#
#                 "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "basename": "AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_clt.nc",
#
#                 "size": 37287280
#
#             }
#
#         ]
#
#     },
#
#     "variable": "pr"
#
# }
#
# DEBUG [job process] path mappings is {
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa",
#
#         "Directory",
#
#         true
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmin.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_pr.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_pr.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_pr.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmax.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tas.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tas.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tas.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmax.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tas.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tas.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tas.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_pr.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_pr.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_pr.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tas.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tas.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tas.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tas.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tas.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tas.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tas.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tas.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tas.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tas.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tas.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tas.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmax.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_KNMI-RACMO2.2b_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_KNMI-RACMO2.2b_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_KNMI-RACMO2.2b_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_pr.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_pr.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_pr.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmin.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmin.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_pr.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_pr.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_pr.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmin.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_pr.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_pr.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_pr.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_pr.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_pr.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_MPI-REMO_CTL_ERAINT_MM_50km_pr.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmin.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmax.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmin.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_CNRM-ARPEGE51_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmin.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmin.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tas.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tas.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tas.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_pr.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_pr.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_SMHI-RCA35_CTL_ERAINT_MM_50km_pr.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_ICTP-REGCM3_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmax.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_IES-CCLM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#         "File",
#
#         false
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_clt.nc",
#
#         "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_clt.nc",
#
#         "File",
#
#         false
#
#     ]
#
# }
#
# DEBUG [job process] command line bindings is [
#
#     {
#
#         "position": [
#
#             -1000000,
#
#             0
#
#         ],
#
#         "datum": "papermill"
#
#     },
#
#     {
#
#         "position": [
#
#             -1000000,
#
#             1
#
#         ],
#
#         "datum": "/home/jovyan/process.ipynb"
#
#     },
#
#     {
#
#         "position": [
#
#             -1000000,
#
#             2
#
#         ],
#
#         "datum": "output_nb.ipynb"
#
#     },
#
#     {
#
#         "position": [
#
#             1,
#
#             "variable"
#
#         ],
#
#         "prefix": "--parameters",
#
#         "shellQuote": false,
#
#         "valueFrom": "variable \"$(self)\"\n",
#
#         "datum": "pr"
#
#     },
#
#     {
#
#         "position": [
#
#             2,
#
#             "dataset_path"
#
#         ],
#
#         "prefix": "--parameters",
#
#         "shellQuote": false,
#
#         "valueFrom": "dataset_path \"$(self.path)\"\n",
#
#         "datum": {
#
#             "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa",
#
#             "basename": "CORDEX_Africa",
#
#             "nameroot": "CORDEX_Africa",
#
#             "nameext": "",
#
#             "class": "Directory",
#
#             "listing": [
#
#                 {
#
#                     "class": "File",
#
#                     "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                     "basename": "AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                     "size": 37446260,
#
#                     "path": "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                     "dirname": "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa",
#
#                     "nameroot": "AFRICA_DMI-HIRHAM_CTL_ERAINT_MM_50km_tasmax",
#
#                     "nameext": ".nc"
#
#                 },
#
#                 {
#
#                     "class": "File",
#
#                     "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/npg8by3y/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                     "basename": "AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                     "size": 37287280,
#
#                     "path": "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa/AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax.nc",
#
#                     "dirname": "/var/lib/cwl/stgc4519c18-9d97-4f67-b7ff-059f503f807d/CORDEX_Africa",
#
#                     "nameroot": "AFRICA_UCT-PRECIS_CTL_ERAINT_MM_50km_tasmax",
#
#                     "nameext": ".nc"
#
#                 },
#
#                 {
#
# ...
#
#         "nameroot": "output_nb",
#
#         "nameext": ".ipynb",
#
#         "class": "File",
#
#         "checksum": "sha1$d398ef3049eadb5e887c75b9b56558720d18a234",
#
#         "size": 175140,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process/CORDEX_Africa_nc": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/CORDEX_Africa_clt.nc",
#
#         "basename": "CORDEX_Africa_clt.nc",
#
#         "nameroot": "CORDEX_Africa_clt",
#
#         "nameext": ".nc",
#
#         "class": "File",
#
#         "checksum": "sha1$ad4e1433ead44d8fdfa3529959c836bf1b641def",
#
#         "size": 142334390,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#process/cordex_africa_png": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/cordex_africa.png",
#
#         "basename": "cordex_africa.png",
#
#         "nameroot": "cordex_africa",
#
#         "nameext": ".png",
#
#         "class": "File",
#
#         "checksum": "sha1$23855c57d40a5e24875c73514bffae6d4a7c18f1",
#
#         "size": 123557,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     }
#
# }
#
# INFO [step process] completed success
#
# shutil.rmtree(/tmp/n0jutbls, True)
#
# DEBUG restore [ram: 1024, cores: 1] to available [ram: 49.74182399999995, cores: 0.0]
#
# INFO [workflow ] starting step stage_out
#
# DEBUG [step stage_out] job input {
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/aws_session_token": "...",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/nb_file": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/output_nb.ipynb",
#
#         "basename": "output_nb.ipynb",
#
#         "nameroot": "output_nb",
#
#         "nameext": ".ipynb",
#
#         "class": "File",
#
#         "checksum": "sha1$d398ef3049eadb5e887c75b9b56558720d18a234",
#
#         "size": 175140,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/nc_file": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/CORDEX_Africa_clt.nc",
#
#         "basename": "CORDEX_Africa_clt.nc",
#
#         "nameroot": "CORDEX_Africa_clt",
#
#         "nameext": ".nc",
#
#         "class": "File",
#
#         "checksum": "sha1$ad4e1433ead44d8fdfa3529959c836bf1b641def",
#
#         "size": 142334390,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/plot": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/cordex_africa.png",
#
#         "basename": "cordex_africa.png",
#
#         "nameroot": "cordex_africa",
#
#         "nameext": ".png",
#
#         "class": "File",
#
#         "checksum": "sha1$23855c57d40a5e24875c73514bffae6d4a7c18f1",
#
#         "size": 123557,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     }
#
# }
#
# DEBUG [step stage_out] evaluated job input to {
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/aws_session_token": "...",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/nb_file": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/output_nb.ipynb",
#
#         "basename": "output_nb.ipynb",
#
#         "nameroot": "output_nb",
#
#         "nameext": ".ipynb",
#
#         "class": "File",
#
#         "checksum": "sha1$d398ef3049eadb5e887c75b9b56558720d18a234",
#
#         "size": 175140,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/nc_file": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/CORDEX_Africa_clt.nc",
#
#         "basename": "CORDEX_Africa_clt.nc",
#
#         "nameroot": "CORDEX_Africa_clt",
#
#         "nameext": ".nc",
#
#         "class": "File",
#
#         "checksum": "sha1$ad4e1433ead44d8fdfa3529959c836bf1b641def",
#
#         "size": 142334390,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl#stage_out/plot": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/cordex_africa.png",
#
#         "basename": "cordex_africa.png",
#
#         "nameroot": "cordex_africa",
#
#         "nameext": ".png",
#
#         "class": "File",
#
#         "checksum": "sha1$23855c57d40a5e24875c73514bffae6d4a7c18f1",
#
#         "size": 123557,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     }
#
# }
#
# INFO [step stage_out] start
#
# DEBUG [job stage_out] initializing from https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/stage_out.cwl as part of step stage_out
#
# DEBUG [job stage_out] {
#
#     "aws_access_key_id": "ASIA434CXH3E3BCHFAN4",
#
#     "aws_secret_access_key": "k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z",
#
#     "aws_session_token": "...",
#
#     "base_dataset_url": "s3://unity-dev-as-s3-analytics/data/",
#
#     "nb_file": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/output_nb.ipynb",
#
#         "basename": "output_nb.ipynb",
#
#         "nameroot": "output_nb",
#
#         "nameext": ".ipynb",
#
#         "class": "File",
#
#         "checksum": "sha1$d398ef3049eadb5e887c75b9b56558720d18a234",
#
#         "size": 175140,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "nc_file": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/CORDEX_Africa_clt.nc",
#
#         "basename": "CORDEX_Africa_clt.nc",
#
#         "nameroot": "CORDEX_Africa_clt",
#
#         "nameext": ".nc",
#
#         "class": "File",
#
#         "checksum": "sha1$ad4e1433ead44d8fdfa3529959c836bf1b641def",
#
#         "size": 142334390,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     },
#
#     "plot": {
#
#         "location": "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/cordex_africa.png",
#
#         "basename": "cordex_africa.png",
#
#         "nameroot": "cordex_africa",
#
#         "nameext": ".png",
#
#         "class": "File",
#
#         "checksum": "sha1$23855c57d40a5e24875c73514bffae6d4a7c18f1",
#
#         "size": 123557,
#
#         "http://commonwl.org/cwltool#generation": 0
#
#     }
#
# }
#
# DEBUG [job stage_out] path mappings is {
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/output_nb.ipynb": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/output_nb.ipynb",
#
#         "/var/lib/cwl/stgf5e8f39f-33c3-45aa-9767-420a12ac90bb/output_nb.ipynb",
#
#         "File",
#
#         true
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/CORDEX_Africa_clt.nc": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/CORDEX_Africa_clt.nc",
#
#         "/var/lib/cwl/stgb276a3ce-7d2b-47e6-ac6a-28c7d04a5433/CORDEX_Africa_clt.nc",
#
#         "File",
#
#         true
#
#     ],
#
#     "file:///calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/cordex_africa.png": [
#
#         "/calrissian/tmpout/tmpout-rd4fir0ojbp2/xlb8x_81/cordex_africa.png",
#
#         "/var/lib/cwl/stg298c558b-6d46-410c-89ab-087a92bd5f93/cordex_africa.png",
#
#         "File",
#
#         true
#
#     ]
#
# }
#
# DEBUG [job stage_out] command line bindings is [
#
#     {
#
#         "position": [
#
#             -1000000,
#
#             0
#
#         ],
#
#         "datum": "sh"
#
#     },
#
#     {
#
#         "position": [
#
#             0,
#
#             0
#
#         ],
#
#         "datum": "-c"
#
#     },
#
#     {
#
#         "position": [
#
#             0,
#
#             1
#
#         ],
#
#         "valueFrom": "cat $HOME/.aws/credentials && aws s3 cp --profile saml-pub $(inputs.nc_file.path) $(inputs.base_dataset_url)stage_out/ && aws s3 cp --profile saml-pub $(inputs.plot.path) $(inputs.base_dataset_url)stage_out/ && aws s3 cp --profile saml-pub $(inputs.nb_file.path) $(inputs.base_dataset_url)stage_out/"
#
#     }
#
# ]
#
# DEBUG wait_for_completion with 0 futures
#
# DEBUG allocate [ram: 256, cores: 1] from available [ram: 1073.741824, cores: 1.0]
#
# DEBUG [job stage_out] initial work dir {
#
#     "_:aa371180-2505-4051-b15d-13bcabdbc23c": [
#
#         "[saml-pub]\noutput = json\nregion = us-west-2\naws_access_key_id = ASIA434CXH3E3BCHFAN4\naws_secret_access_key = k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z\naws_session_token = ...\n",
#
#         "/KQUXQs/.aws/credentials",
#
#         "CreateFile",
#
#         true
#
#     ]
#
# }
#
# Building resources spec from {'cores': 1, 'ram': 256}
#
# DEBUG wait_for_completion with 1 futures
#
# --------------------------------------------------------------------------------
#
# apiVersion: v1
#
# kind: Pod
#
# metadata:
#
#   labels:
#
#     job-name: calrissian-job-rd4fir0ojbp2
#
#   name: stage-out-pod-jacqfebv
#
# spec:
#
#   containers:
#
#   - args:
#
#     - sh -c 'cat $HOME/.aws/credentials && aws s3 cp --profile saml-pub /var/lib/cwl/stgb276a3ce-7d2b-47e6-ac6a-28c7d04a5433/CORDEX_Africa_clt.nc
#
#       s3://unity-dev-as-s3-analytics/data/stage_out/ && aws s3 cp --profile saml-pub
#
#       /var/lib/cwl/stg298c558b-6d46-410c-89ab-087a92bd5f93/cordex_africa.png s3://unity-dev-as-s3-analytics/data/stage_out/
#
#       && aws s3 cp --profile saml-pub /var/lib/cwl/stgf5e8f39f-33c3-45aa-9767-420a12ac90bb/output_nb.ipynb
#
#       s3://unity-dev-as-s3-analytics/data/stage_out/'
#
#     command:
#
#     - /bin/sh
#
#     - -c
#
#     env:
#
#     - name: HOME
#
#       value: /KQUXQs
#
#     - name: TMPDIR
#
#       value: /tmp
#
#     image: jplzhan/ci-generated-images:unity-sds.unity-analytics-bcdp.main
#
#     imagePullPolicy: Always
#
#     name: stage-out-container
#
#     resources:
#
#       requests:
#
#         cpu: '1'
#
#         memory: 256Mi
#
#     volumeMounts:
#
#     - mountPath: /KQUXQs
#
#       name: tmpout-rd4fir0ojbp2
#
#       readOnly: false
#
#       subPath: tmpout-rd4fir0ojbp2/n_lavdld
#
#     - mountPath: /tmp
#
#       name: tmpdir
#
#     - mountPath: /var/lib/cwl/stgf5e8f39f-33c3-45aa-9767-420a12ac90bb/output_nb.ipynb
#
#       name: tmpout-rd4fir0ojbp2
#
#       readOnly: true
#
#       subPath: tmpout-rd4fir0ojbp2/xlb8x_81/output_nb.ipynb
#
#     - mountPath: /var/lib/cwl/stgb276a3ce-7d2b-47e6-ac6a-28c7d04a5433/CORDEX_Africa_clt.nc
#
#       name: tmpout-rd4fir0ojbp2
#
#       readOnly: true
#
#       subPath: tmpout-rd4fir0ojbp2/xlb8x_81/CORDEX_Africa_clt.nc
#
#     - mountPath: /var/lib/cwl/stg298c558b-6d46-410c-89ab-087a92bd5f93/cordex_africa.png
#
#       name: tmpout-rd4fir0ojbp2
#
#       readOnly: true
#
#       subPath: tmpout-rd4fir0ojbp2/xlb8x_81/cordex_africa.png
#
#     workingDir: /KQUXQs
#
#   initContainers: []
#
#   restartPolicy: Never
#
#   securityContext:
#
#     runAsGroup: 0
#
#     runAsUser: 1001
#
#   volumes:
#
#   - name: tmpout-rd4fir0ojbp2
#
#     persistentVolumeClaim:
#
#       claimName: tmpout-rd4fir0ojbp2
#
#       readOnly: false
#
#   - name: output-data-rd4fir0ojbp2
#
#     persistentVolumeClaim:
#
#       claimName: output-data-rd4fir0ojbp2
#
#       readOnly: false
#
#   - emptyDir: {}
#
#     name: tmpdir
#
# --------------------------------------------------------------------------------
#
#
#
# Created k8s pod name stage-out-pod-jacqfebv with id f33b574b-a1fa-4e24-92e9-bae29b79f0c6
#
# PodMonitor adding stage-out-pod-jacqfebv
#
# k8s pod 'stage-out-pod-jacqfebv' started
#
# [stage-out-pod-jacqfebv] follow_logs start
#
# [stage-out-pod-jacqfebv] [saml-pub]
#
# [stage-out-pod-jacqfebv] output = json
#
# [stage-out-pod-jacqfebv] region = us-west-2
#
# [stage-out-pod-jacqfebv] aws_access_key_id = ASIA434CXH3E3BCHFAN4
#
# [stage-out-pod-jacqfebv] aws_secret_access_key = k3HO5PZiJ5vIctpH+olT+bNK3ktnJlycg8JeXE4z
#
# [stage-out-pod-jacqfebv] aws_session_token = ...
#
# Completed 59.2 MiB/135.7 MiB (4.6 MiB/s) with 1 file(s) remaining    with 1 file(s) remaining
# ted 59.5 MiB/135.7 MiB (4
#
# Completed 118.8 MiB/135.7 MiB (4.7 MiB/s) with 1 file(s) remaining
# B/s) with 1 file(s) remai
#
# upload: ../var/lib/cwl/stgb276a3ce-7d2b-47e6-ac6a-28c7d04a5433/CORDEX_Africa_clt.nc to s3://unity-dev-as-s3-analytics/data/stage_out/CORDEX_Africa_clt.nc
#
# upload: ../var/lib/cwl/stg298c558b-6d46-410c-89ab-087a92bd5f93/cordex_africa.png to s3://unity-dev-as-s3-analytics/data/stage_out/cordex_africa.png
#
# upload: ../var/lib/cwl/stgf5e8f39f-33c3-45aa-9767-420a12ac90bb/output_nb.ipynb to s3://unity-dev-as-s3-analytics/data/stage_out/output_nb.ipynb
#
# [stage-out-pod-jacqfebv] follow_logs end
#
# Handling terminated pod name stage-out-pod-jacqfebv with id f33b574b-a1fa-4e24-92e9-bae29b79f0c6
#
# handling completion with 0
#
# CALRISSIAN_DELETE_PODS=false(<class 'str'>)
#
# returning False
#
# DEBUG [step stage_out] produced output {}
#
# INFO [step stage_out] completed success
#
# INFO [workflow ] completed success
#
# DEBUG [workflow ] outputs {}
#
# shutil.rmtree(/tmp/qop2g67s, True)
#
# DEBUG restore [ram: 256, cores: 1] to available [ram: 817.741824, cores: 0.0]
#
# DEBUG wait_for_completion with 0 futures
#
# DEBUG wait_for_completion with 0 futures
#
# DEBUG Finishing ThreadPoolExecutor.run_jobs: total_resources=[ram: 1073.741824, cores: 1.0], available_resources=[ram: 1073.741824, cores: 1.0]
#
# INFO Final process status is success
#
# {}
#
# CALRISSIAN_DELETE_PODS=false(<class 'str'>)
#
# returning False
#
# # BEGIN docker-usage.json
#
# {
#
#     "cores_allowed": 1.0,
#
#     "ram_mb_allowed": 1073.741824,
#
#     "children": [
#
#         {
#
#             "cpus": 1.0,
#
#             "ram_megabytes": 268.435456,
#
#             "disk_megabytes": 0.0,
#
#             "name": "stage_in",
#
#             "start_time": "2022-08-15T19:57:31+00:00",
#
#             "finish_time": "2022-08-15T20:00:21+00:00",
#
#             "elapsed_hours": 0.04722222222222222,
#
#             "elapsed_seconds": 170.0,
#
#             "ram_megabyte_hours": 12.676118755555555,
#
#             "cpu_hours": 0.04722222222222222
#
#         },
#
#         {
#
#             "cpus": 1.0,
#
#             "ram_megabytes": 1073.741824,
#
#             "disk_megabytes": 142.633087,
#
#             "name": "process",
#
#             "start_time": "2022-08-15T20:00:24+00:00",
#
#             "finish_time": "2022-08-15T20:00:59+00:00",
#
#             "elapsed_hours": 0.009722222222222222,
#
#             "elapsed_seconds": 35.0,
#
#             "ram_megabyte_hours": 10.439156622222223,
#
#             "cpu_hours": 0.009722222222222222
#
#         },
#
#         {
#
#             "cpus": 1.0,
#
#             "ram_megabytes": 268.435456,
#
#             "disk_megabytes": 0.0,
#
#             "name": "stage_out",
#
#             "start_time": "2022-08-15T20:01:05+00:00",
#
#             "finish_time": "2022-08-15T20:01:43+00:00",
#
#             "elapsed_hours": 0.010555555555555556,
#
#             "elapsed_seconds": 38.0,
#
#             "ram_megabyte_hours": 2.833485368888889,
#
#             "cpu_hours": 0.010555555555555556
#
#         }
#
#     ],
#
#     "start_time": "2022-08-15T19:57:31+00:00",
#
#     "finish_time": "2022-08-15T20:01:43+00:00",
#
#     "elapsed_hours": 0.07,
#
#     "elapsed_seconds": 252.0,
#
#     "total_cpu_hours": 0.0675,
#
#     "total_ram_megabyte_hours": 25.948760746666665,
#
#     "total_disk_megabytes": 142.633087,
#
#     "total_tasks": 3,
#
#     "max_parallel_cpus": 1.0,
#
#     "max_parallel_ram_megabytes": 1073.741824,
#
#     "max_parallel_tasks": 1
#
# }
#
# # END docker-usage.json

# %% [markdown]
# Confirm job result in ADES

# %%
job = jobs['jobs'][0]
ades_client.getResult(proc['id'], job['jobID'])
# Out:
# {'jobID': 'unity-sds.unity-analytics-bcdp.main-3.0.0-0083d93af77e542be7df64d1d5b3a3da4afd0b44',
#  'links': [{'href': 'https://mypath',
#    'rel': 'result',
#    'title': 'mytitle',
#    'type': 'application/json'}],
#  'status': 'successful'}

# %% [markdown]
# Undeploy the process from the ADES and cleanup any k8s pods

# %%
ades_client.undeployProcess(proc['id'])
# Out:
# {'undeploymentResult': {'abstract': 'Application Package Demo',
#   'executionUnit': 'docker://jplzhan/ci-generated-images:unity-sds.unity-analytics-bcdp.main',
#   'id': 'unity-sds.unity-analytics-bcdp.main-3.0.0',
#   'immediateDeployment': 'true',
#   'jobControlOptions': ['async-execute'],
#   'keywords': 'Demo',
#   'outputTransmission': ['reference'],
#   'owsContextURL': 'https://raw.githubusercontent.com/unity-sds/unity-analytics-bcdp/main/workflow.cwl',
#   'processVersion': '3.0.0',
#   'title': 'BCDP'}}

# %%
kube_client.delete_collection_namespaced_pod('ades')
# Out:
# {'api_version': 'v1',
#  'code': None,
#  'details': None,
#  'kind': 'PodList',
#  'message': None,
#  'metadata': {'_continue': None,
#               'remaining_item_count': None,
#               'resource_version': '248750',
#               'self_link': None},
#  'reason': None,
#  'status': None}
